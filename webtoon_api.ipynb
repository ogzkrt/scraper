# %%
import bs4
from typing import List
import requests
import os
import tqdm
import pandas as pd
import json
import numpy as np

# %%
def string_to_enum(s):
    
    s = s.replace(' ','_')
    s = s.replace('-','_')
    
    return s

# %%
def convert_abv(s):
    ab_dict = {'K':1000,'M':1000000,'B':1000000000}
    
    if s[-1].isdigit():
        if ',' in s:
            s = s.replace(',','')
        return int(s)
    
    return int(float(s[:-1]) * ab_dict[s[-1]])

# %%
def scrape_genres():
    url = 'https://www.webtoons.com/en/genre'
    resp = requests.get(url)
    soup = bs4.BeautifulSoup(resp.content,'html.parser')
    
    visibles = soup.find('ul',{'class':'snb _genre'})
    hiddens = soup.find('ul',{'class':'ly_lst_genre as_genre'})
    
    visible_genres = visibles.find_all('li')
    hidden_genres = hiddens.find_all('li')

    genres = [g['data-genre'] for g in visible_genres[:-1]+hidden_genres]
    return genres

# %%
def scrape_details(url):
    
    resp = requests.get(url)
    soup = bs4.BeautifulSoup(resp.content,'html.parser')
    
    info_div = soup.find('div',{'class':'info'})
    genre = info_div.find('h2').text
    grade_area = soup.find('ul',{'class':'grade_area'})
    back_div = soup.find('div',{'class':'detail_header'})
    
    details = soup.find('div',{'class':'aside detail'})
    summary = details.find('p',{'class':'summary'}).text
    day_info = details.find('p',{'class':'day_info'}).text
    back_img_url = back_div.find('img')['src']
    
    grade_area = [x.text for x in grade_area.find_all('em')]
    view, follower, rate = grade_area
    
    view = convert_abv(view)
    follower = convert_abv(follower)
    
    #day info UPEVERY WEDNESDAY -> WEDNESDAY
    if len(day_info.split(' '))==2:
        day_info = day_info.split(' ')[1]
    
    genre = string_to_enum(genre)
    
    return {
        'summary':summary,
        'day_info':day_info,
        'genre':genre,
        'view':view,
        'follower':follower,
        'rate':rate,
        'back_img_url':back_img_url
           }

# %%
def get_all_mangas(url,limit=2):
    data = []
    resp = requests.get(url)
    soup = bs4.BeautifulSoup(resp.content,'html.parser')

    card_list = soup.find('ul',{'class':'card_lst'})
    cards = card_list.find_all('li')
    
    for c in tqdm.tqdm(cards[:limit]):

        subj = c.find('p',{'class':'subj'}).text
        author = c.find('p',{'class':'author'}).text
        grade = c.find('em',{'class':'grade_num'}).text
        link = c.find('a')['href']
        tumbnail = c.find('a').find('img')['src']
        
        
        grade = convert_abv(grade)
        d = scrape_details(link)

        tmp = {
            'name':subj,
            'author':author,
            'grade':grade,
            'genre':d['genre'],
            'summary':d['summary'],
            'day_info':d['day_info'],
            'view':d['view'],
            'follower':d['follower'],
            'rate':d['rate'],
            'link':link,
            'tumbnail':tumbnail,
            'back_img_url':d['back_img_url']

        }

        data.append(tmp)
    df = pd.DataFrame(data)
    return df

# %%
df = get_all_mangas('https://www.webtoons.com/en/genre',500)
df
# Out:
# 100%|█████████████████████████████████████████| 241/241 [02:26<00:00,  1.65it/s]
#                             name                              author  \
# 0          The Remarried Empress                  Alphatart / Sumpul
# 1                    True Beauty                             Yaongyi
# 2            Midnight Poppy Land                            Lilydusk
# 3                        Reunion                          stephattyy
# 4              Teenage Mercenary                        YC / Rakyeon
# ..                           ...                                 ...
# 236           The Shadow Prophet  Anne Delseit / Marissa Delbressine
# 237      In the Bleak Midwinter;                           Kat / Ali
# 238        Unlovable Replacement                              Nylana
# 239        Version Day and Night                        dewkneelight
# 240  The Devil is a Handsome Man                    Hellothisisangle
#
#         grade    genre                                            summary  \
# 0    22100000  Fantasy  Navier Ellie Trovi was an empress perfect in e...
# 1    46800000  Romance  After binge-watching beauty videos online, a s...
# 2    13900000  Romance  After making a grisly discovery in the country...
# 3      867255  Romance  After moving away for a decade, Rhea returns t...
# 4     4000000   Action  At the age of eight, Ijin Yu lost his parents ...
# ..        ...      ...                                                ...
# 236    303443    Drama  The Great Prophet Godo has a place for everyon...
# 237   2400000   Sci_fi  With a dead sister and 25 years to go on her s...
# 238   6000000  Romance  When his relationship went down the drain, Chi...
# 239   1100000    Drama  Candy always dreamed of something more excitin...
# 240   2400000    Drama  Xolia makes the deal with the devil in order t...
#
#       day_info       view  follower  rate  \
# 0       SUNDAY  241700000   2600000  9.87
# 1    WEDNESDAY  885100000   7000000  9.52
# 2     SATURDAY  203300000   2300000  9.80
# 3       FRIDAY   11500000    707935  9.77
# 4    WEDNESDAY   45700000   1000000  9.86
# ..         ...        ...       ...   ...
# 236     SUNDAY    1800000     91067  9.55
# 237  WEDNESDAY   21600000    588535  9.77
# 238   THURSDAY   76700000   1500000  9.77
# 239     FRIDAY   10400000    480302  9.52
# 240  WEDNESDAY   31400000    775530  9.55
#
#                                                   link  \
# 0    https://www.webtoons.com/en/fantasy/the-remarr...
# 1    https://www.webtoons.com/en/romance/truebeauty...
# 2    https://www.webtoons.com/en/romance/midnight-p...
# 3    https://www.webtoons.com/en/romance/reunion/li...
# 4    https://www.webtoons.com/en/action/teenage-mer...
# ..                                                 ...
# 236  https://www.webtoons.com/en/drama/the-shadow-p...
# 237  https://www.webtoons.com/en/sf/in-the-bleak-mi...
# 238  https://www.webtoons.com/en/romance/unlovable-...
# 239  https://www.webtoons.com/en/drama/version-day-...
# 240  https://www.webtoons.com/en/drama/the-devil-is...
#
#                                               tumbnail  \
# 0    https://webtoon-phinf.pstatic.net/20200904_268...
# 1    https://webtoon-phinf.pstatic.net/20210129_65/...
# 2    https://webtoon-phinf.pstatic.net/20191119_163...
# 3    https://webtoon-phinf.pstatic.net/20220311_14/...
# 4    https://webtoon-phinf.pstatic.net/20210430_189...
# ..                                                 ...
# 236  https://webtoon-phinf.pstatic.net/20210329_188...
# 237  https://webtoon-phinf.pstatic.net/20210329_117...
# 238  https://webtoon-phinf.pstatic.net/20210329_185...
# 239  https://webtoon-phinf.pstatic.net/20210329_80/...
# 240  https://webtoon-phinf.pstatic.net/20210329_31/...
#
#                                           back_img_url
# 0    https://webtoon-phinf.pstatic.net/20200904_29/...
# 1    https://webtoon-phinf.pstatic.net/20210129_175...
# 2    https://webtoon-phinf.pstatic.net/20191119_132...
# 3    https://webtoon-phinf.pstatic.net/20220311_196...
# 4    https://webtoon-phinf.pstatic.net/20210430_11/...
# ..                                                 ...
# 236  https://webtoon-phinf.pstatic.net/20200125_134...
# 237  https://webtoon-phinf.pstatic.net/20200312_45/...
# 238  https://webtoon-phinf.pstatic.net/20191029_163...
# 239  https://webtoon-phinf.pstatic.net/20191114_100...
# 240  https://webtoon-phinf.pstatic.net/20180214_69/...
#
# [241 rows x 12 columns]

# %%
df['day_info'].value_counts()
# Out:
# COMPLETED           104
# SATURDAY             25
# TUESDAY              25
# WEDNESDAY            21
# SUNDAY               19
# FRIDAY               19
# MONDAY               17
# THURSDAY             10
# UPEVERY MON, THU      1
# Name: day_info, dtype: int64

# %%
def send_req(x):
    name,author,grade,genre,summary,day_info,view,follower,rate,link,tumbnail,back_img = x
    url = "http://localhost:8080/add"

    payload = json.dumps({
      "id": 122,
      "name": name,
      "authorName":author,
      "genre":genre.upper(),
      "description":summary,
      "followerNumber": follower,
      "viewNumber": view,
      "rate": rate,
      "newEpisodeDay":day_info.upper(),
      "tumbnailURL": tumbnail,
      "backgroudImageURL": back_img
    },default= lambda x: x.item() if isinstance(x,np.generic) else x)
    headers = {
      'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)

# %%
df.apply(lambda x: send_req(x),axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 236    None
# 237    None
# 238    None
# 239    None
# 240    None
# Length: 241, dtype: object

# %%
def get_episodes(url):
    resp = requests.get(url)
    soup = bs4.BeautifulSoup(resp.content,'html.parser')
    episodes = soup.find('ul',{'id':'_listUl'})
    episodes = episodes.find_all('li')
    
    result = []
    for episode in episodes:
        episode_img = episode.find('img')['src']
        episode_num = episode.find('span',{'class':'subj'}).text
        episode_date = episode.find('span',{'class':'date'}).text
        episode_likes = episode.find('span',{'class':'like_area'}).text[4:] #like123,23

        result.append({
            'episode_img':episode_img,
            'episode_num':episode_num,
            'episode_date':episode_date,
            'episode_lies':episode_likes
        })
    return result

# %%
get_episodes('https://www.webtoons.com/en/romance/truebeauty/list?title_no=1436')
# Out:
# [{'episode_img': 'https://webtoon-phinf.pstatic.net/20220322_207/1647935465711Udp8U_PNG/thumb_164793532601414362010.png?type=q90',
#   'episode_num': 'Episode 200',
#   'episode_date': 'May 31, 2022',
#   'episode_lies': '71,627'},
#  {'episode_img': 'https://webtoon-phinf.pstatic.net/20220322_242/1647935300738jmJ6D_PNG/thumb_164793495411114362004.png?type=q90',
#   'episode_num': 'Episode 199',
#   'episode_date': 'May 24, 2022',
#   'episode_lies': '89,953'},
#  {'episode_img': 'https://webtoon-phinf.pstatic.net/20220322_273/16479349315486199w_PNG/thumb_164793482947314361998.png?type=q90',
#   'episode_num': 'Episode 198',
#   'episode_date': 'May 17, 2022',
#   'episode_lies': '98,305'},
#  {'episode_img': 'https://webtoon-phinf.pstatic.net/20220307_289/16466517239892QIh6_PNG/thumb_164665164509914361983.png?type=q90',
#   'episode_num': 'Episode 197',
#   'episode_date': 'May 10, 2022',
#   'episode_lies': '97,465'},
#  {'episode_img': 'https://webtoon-phinf.pstatic.net/20220307_123/164665146929293txK_PNG/thumb_164665084208014361970.png?type=q90',
#   'episode_num': 'Episode 196',
#   'episode_date': 'May 3, 2022',
#   'episode_lies': '102,145'},
#  {'episode_img': 'https://webtoon-phinf.pstatic.net/20220215_169/1644914954037WWDy3_JPEG/164491495402314361963.jpg?type=q90',
#   'episode_num': 'Episode 195',
#   'episode_date': 'Apr 26, 2022',
#   'episode_lies': '108,864'},
#  {'episode_img': 'https://webtoon-phinf.pstatic.net/20220215_216/1644914858308FzLq5_JPEG/164491485829514361959.jpg?type=q90',
#   'episode_num': 'Episode 194',
#   'episode_date': 'Apr 19, 2022',
#   'episode_lies': '107,975'},
#  {'episode_img': 'https://webtoon-phinf.pstatic.net/20220215_121/16449111489718df3W_JPEG/164491114896314361947.jpg?type=q90',
#   'episode_num': 'Episode 193',
#   'episode_date': 'Apr 12, 2022',
#   'episode_lies': '131,054'},
#  {'episode_img': 'https://webtoon-phinf.pstatic.net/20220208_90/1644314341201JAnRx_PNG/thumb_164427070106614361934.png?type=q90',
#   'episode_num': 'Episode 192',
#   'episode_date': 'Apr 5, 2022',
#   'episode_lies': '116,459'},
#  {'episode_img': 'https://webtoon-phinf.pstatic.net/20220127_168/1643280682037n8UST_JPEG/164328068203114361920.jpg?type=q90',
#   'episode_num': 'Episode 191',
#   'episode_date': 'Mar 29, 2022',
#   'episode_lies': '117,091'}]

# %%
# traverse
resp = requests.get('https://www.webtoons.com/en/romance/truebeauty/episode-0-/viewer?title_no=1436&episode_no=1')
soup = bs4.BeautifulSoup(resp.content,'html.parser')

# %%
try:
    soup.find('a',{'class':'pg_next'})['href']
except Exception as e:
    print(e)
# Out:
# 'https://www.webtoons.com/en/romance/truebeauty/episode-1/viewer?title_no=1436&episode_no=2'

# %%
def get_image_links_and_next(url):
    resp = requests.get(url)
    soup = bs4.BeautifulSoup(resp.content,'html.parser')
    print(soup.find('h1',{'class':'subj_episode'}).text)
    next_link = None
    try:
        next_link = soup.find('a',{'class':'pg_next'})['href']
    except Exception as e:
        print(e)
    return [], next_link

# %%
def get_all_episodes(url):
    _, next_exist = get_image_links_and_next(url)
    while next_exist and next_exist !='#':
        _,next_exist = get_image_links_and_next(next_exist)
    print('finished')

# %%
get_all_episodes('https://www.webtoons.com/en/romance/truebeauty/episode-199/viewer?title_no=1436&episode_no=200')
# Out:
# Episode 199
# Episode 200
# finished

# %%
resp = requests.get('https://www.webtoons.com/en/romance/truebeauty/list?title_no=1436')
soup = bs4.BeautifulSoup(resp.content,'html.parser')

# %%
pagi = soup.find('div',{'class':'paginate'})

# %%
def ge_and_pagination(url,visited):
    print('Start with '+url)
    if url not in visited:
        visited.add(url)
        resp = requests.get(url)
        soup = bs4.BeautifulSoup(resp.content,'html.parser')
        pagi = soup.find('div',{'class':'paginate'})
        base_url = 'https://webtoons.com'
        result = []

        pag_nums = pagi.find_all('a')

        for p in pagi.find_all('a')[1:]:
            if p['href'] != '#':
                print(base_url+p['href'])
                a = get_episodes(base_url+p['href'])
                result.append(a)
        x = base_url+p['href']
        ge_and_pagination(x,visited)

# %%
r = ge_and_pagination('https://www.webtoons.com/en/romance/truebeauty/list?title_no=1436',set())
# Out:
# Start with https://www.webtoons.com/en/romance/truebeauty/list?title_no=1436
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=2
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=3
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=4
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=5
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=6
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=7
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=8
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=9
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=10
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=11
# Start with https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=11
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=12
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=13
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=14
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=15
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=16
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=17
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=18
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=19
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=20
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=21
# Start with https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=21
# Start with https://webtoons.com#
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3575/2095322157.py in <module>
# ----> 1 r = ge_and_pagination('https://www.webtoons.com/en/romance/truebeauty/list?title_no=1436',set())
#
# /tmp/ipykernel_3575/4219709752.py in ge_and_pagination(url, visited)
#      17                 result.append(a)
#      18         x = base_url+p['href']
# ---> 19         ge_and_pagination(x,visited)
#
# /tmp/ipykernel_3575/4219709752.py in ge_and_pagination(url, visited)
#      17                 result.append(a)
#      18         x = base_url+p['href']
# ---> 19         ge_and_pagination(x,visited)
#
# /tmp/ipykernel_3575/4219709752.py in ge_and_pagination(url, visited)
#      17                 result.append(a)
#      18         x = base_url+p['href']
# ---> 19         ge_and_pagination(x,visited)
#
# /tmp/ipykernel_3575/4219709752.py in ge_and_pagination(url, visited)
#       9         result = []
#      10
# ---> 11         pag_nums = pagi.find_all('a')
#      12
#      13         for p in pagi.find_all('a')[1:]:
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
url = 'https://www.webtoons.com/en/romance/truebeauty/list?title_no=1436'
base_url = 'https://webtoons.com'
for p in pagi.find_all('a')[1:]:
    print(base_url+p['href'])
# Out:
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=2
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=3
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=4
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=5
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=6
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=7
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=8
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=9
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=10
# https://webtoons.com/en/romance/truebeauty/list?title_no=1436&page=11

# %%
def dummy(url):
    base_url = 'https://webtoons.com'
    result = []
    for p in pagi.find_all('a')[1:]:
        print(base_url+p['href'])
        a = get_episodes(base_url+p['href'])
        result.append(a)
    x = base_url+p['href']
    print('new round',x)
    ge_and_pagination(x)
